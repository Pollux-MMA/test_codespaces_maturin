# %%
# !pip install "test_codespaces_maturin/target/wheels/test_codespaces_maturin-0.1.0-cp312-cp312-manylinux_2_34_x86_64.whl"
# Out:
# Processing ./test_codespaces_maturin/target/wheels/test_codespaces_maturin-0.1.0-cp312-cp312-manylinux_2_34_x86_64.whl
# ...
#
# [notice] A new release of pip is available: 26.0.1 -> 26.1.2
# [notice] To update, run: python3 -m pip install --upgrade pip

# %%
import test_codespaces_maturin
test_codespaces_maturin.sum_as_string(1, 2)
# Out:
# '3'
